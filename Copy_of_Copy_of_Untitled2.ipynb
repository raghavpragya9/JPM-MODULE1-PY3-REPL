# %% [markdown]
# <a href="https://colab.research.google.com/github/raghavpragya9/JPM-MODULE1-PY3-REPL/blob/main/Copy_of_Copy_of_Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
newfile=pd.read_excel('new copy.xlsx')

# %%
newfile.describe()
# Out:
#                   a             b             c             d             e  \
# count  22506.000000  22506.000000  22506.000000  22506.000000  22506.000000
# mean     355.394828     11.619235     16.597662      2.055018    215.099125
# std      193.735702      6.891953      5.241631      1.335975     17.848557
# min        1.000000      0.000000      8.592541      0.329252    185.994827
# 25%      181.000000      5.500000     12.701748      0.930583    199.764656
# 50%      355.000000     12.000000     15.650223      1.447720    211.569999
# 75%      521.000000     17.500000     18.922676      3.252273    229.249584
# max      684.000000     23.500000     68.664917      6.619331    295.302795
#
#                   f             g             h             i             k  \
# count  22506.000000  22506.000000  22506.000000  22506.000000  22506.000000
# mean       1.110713    223.751596      0.486923     19.858540      0.957529
# ...

# %%
newfile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22506 entries, 0 to 22505
# Data columns (total 34 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       22506 non-null  int64
#  1   b       22506 non-null  float64
#  2   c       22506 non-null  float64
#  3   d       22506 non-null  float64
#  4   e       22506 non-null  float64
#  5   f       22506 non-null  float64
#  6   g       22506 non-null  float64
#  7   h       22506 non-null  float64
#  8   i       22506 non-null  float64
#  9   j       22506 non-null  object
#  10  k       22506 non-null  float64
#  11  l       22506 non-null  object
#  12  m       22506 non-null  float64
#  13  n       22506 non-null  object
#  14  o       22506 non-null  object
#  15  p       22506 non-null  object
#  16  q       22506 non-null  object
#  17  r       22506 non-null  float64
#  18  s       22506 non-null  float64
#  19  t       22506 non-null  object
#  20  u       22506 non-null  object
# ...

# %%
newfile['h']
# Out:
# 0        4.198429
# 1        0.386569
# 2        0.806805
# 3        0.398740
# 4        0.397431
#            ...
# 22501    0.642312
# 22502    0.643026
# 22503    0.599102
# 22504    0.591796
# 22505    0.609904
# Name: h, Length: 22506, dtype: float64

# %%
d=newfile.iloc[:,3]
# Out:
# 0        4.380811
# 1        4.445973
# 2        2.319761
# 3        1.001678
# 4        0.978869
#            ...
# 22501    1.622734
# 22502    1.487368
# 22503    1.209786
# 22504    1.137914
# 22505    1.105117
# Name: d, Length: 22506, dtype: float64

# %%
q1=newfile.d.quantile(0.25)

# %%
q3=newfile.d.quantile(0.75)

# %%
IQR=q3-q1

# %%
print(IQR)
# Out:
# 2.3216900480000002

# %%
max_threshold=newfile['d'].quantile(0.99)

# %%
min_threshold=newfile['d'].quantile(0.05)

# %%
newfile[newfile['d']<min_threshold]
# Out:
#          a    b          c         d           e         f           g  \
# 1770    70  3.5  13.752644  0.340332  196.612869  2.160654  200.609253
# 1810    71  3.5  14.247269  0.341757  198.393143  2.198222  200.951920
# 1849    72  3.5  14.123184  0.342003  197.312622  2.135241  201.296982
# 1889    73  3.5  14.961980  0.344466  202.875305  2.240138  199.147034
# 1928    74  3.5  14.637821  0.348281  199.940063  2.061467  199.852707
# ...    ...  ...        ...       ...         ...       ...         ...
# 21917  669  7.0  10.377787  0.668405  192.127701  0.900926  187.465607
# 21955  670  6.5  10.524805  0.658699  194.917297  0.904353  185.602341
# 22067  673  7.0  10.161503  0.661645  192.536865  0.906215  189.247147
# 22405  682  6.5  10.807529  0.667714  195.040955  0.892255  182.785477
# 22479  684  6.5  10.769227  0.668486  196.248871  0.914610  182.931046
#
#               h         i         j  ...  \
# 1770   0.724505  0.674924  0.100832  ...
# ...

# %%
newfile[newfile['d']>max_threshold]
# Out:
#          a     b          c         d           e         f           g  \
# 11      15  15.0  67.266762  5.811514  249.391129  1.982938  258.568390
# 46      16  14.0  67.037766  5.831876  247.385498  1.930313  258.189392
# 49      16  16.0  56.606529  5.410996  241.920715  1.410897  256.556061
# 5657   184  14.0  45.406372  5.660045  245.136810  2.189397  268.173279
# 5659   184  15.0  68.664917  6.619331  253.906921  2.462290  264.147430
# ...    ...   ...        ...       ...         ...       ...         ...
# 12753  401  14.0  28.614012  5.470644  250.990051  1.804643  278.163269
# 12754  401  15.0  28.102158  5.594186  250.680740  1.936334  264.283752
# 12789  402  14.0  28.248333  5.414165  250.231262  1.867642  272.403351
# 12816  402  14.0  28.248333  5.414165  250.231262  1.867642  272.403351
# 17597  538  15.0  22.473681  5.400590  238.737106  2.616007  261.373810
#
#               h          i         j  ...  \
# 11     1.162259  20.163629  3.597307  ...
# ...

# %%
newfile[(newfile['d']<max_threshold)&(newfile['d']>min_threshold)]
# Out:
#          a     b          c         d           e         f           g  \
# 0        1  16.5  17.992321  4.380811  240.401108  1.457962  185.030090
# 1        2  16.5  18.559444  4.445973  239.735291  2.411693  252.832077
# 2        9  11.5  22.082247  2.319761  224.297241  2.598618  258.689301
# 3       15   0.0  13.071298  1.001678  203.022644  0.740632  203.011322
# 4       15   0.5  13.106343  0.978869  203.721893  0.730900  202.748413
# ...    ...   ...        ...       ...         ...       ...         ...
# 22501  684  20.5  16.047237  1.622734  215.863693  0.857852  204.778122
# 22502  684  21.0  15.513002  1.487368  214.181641  0.823952  202.005905
# 22503  684  22.0  14.796203  1.209786  211.907272  0.790952  198.097961
# 22504  684  22.5  14.582492  1.137914  211.766510  0.804547  196.717575
# 22505  684  23.0  14.355341  1.105117  209.917099  0.801991  195.289398
#
#               h          i         j  ...  \
# 0      4.198429  88.302856  4.860013  ...
# ...
